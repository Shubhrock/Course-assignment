# %%
# Consider following code to answer further questions:

import pandas as pd
course_name = ['Data Science', 'Machine Learning', 'Big Data', 'Data Engineer']
duration =  [2,3,6,4]
df = pd.DataFrame(data = {'course_name' : course_name, 'duration' : duration})

# Slolution 1
# Q1. Write a code to print the data present in the second row of the dataframe, df.

df.loc[1:1, ['course_name','duration']]
# Out:
#         course_name  duration
# 1  Machine Learning         3

# %%
# Solution 2
#  What is the difference between the functions loc and iloc in pandas.DataFrame?

# DataFrame.loc[] is label-based to select rows and/or columns in pandas. It accepts single labels, multiple labels from the list, indexes by a range (between two indexes labels), and many more.
# DataFrame.iloc[] is a index-based to select rows and/or columns in pandas. It accepts a single index, multiple indexes from the list, indexes by a range, and many more.

# %%
# Solution 3

# Reindex the given dataframe using a variable, reindex = [3,0,1,2] and store it in the variable, new_df
# then find the output for both new_df.loc[2] and new_df.iloc[2].

import pandas as pd

data = {'Courses' : ["Spark","PySpark","Hadoop","Python","pandas"]
}

df = pd.DataFrame(data)
df

reindex = [3,0,1,4,2]

new_df = df.reindex(reindex)
new_df
# Out:
#    Courses
# 3   Python
# 0    Spark
# 1  PySpark
# 4   pandas
# 2   Hadoop

# %%
new_df.loc[2]
# Out:
# Courses    Hadoop
# Name: 2, dtype: object

# %%
new_df.iloc[2]
# Out:
# Courses    PySpark
# Name: 1, dtype: object

# %%
DataFrame.loc function returns the data at the named index 2
DataFrame.iloc function returns the data at integer index 2 of the DataFrame

# %%
# Consider the below code to answer further questions:
import pandas as pd

import numpy as np

columns = ['column_1', 'column_2', 'column_3', 'column_4', 'column_5', 'column_6']

indices = [1,2,3,4,5,6]

#Creating a dataframe:

df1 = pd.DataFrame(np.random.rand(6,6), columns = columns, index = indices)

# %%
# Solution 4

df1
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6
# 1  0.511025  0.694619  0.036682  0.199129  0.095474  0.662907
# 2  0.429061  0.362043  0.950979  0.923716  0.516688  0.037985
# 3  0.884393  0.098448  0.142266  0.782230  0.194359  0.184436
# 4  0.991547  0.723847  0.516183  0.507132  0.920445  0.437374
# 5  0.677529  0.772872  0.022432  0.606828  0.894357  0.734966
# 6  0.142280  0.079979  0.853109  0.937346  0.553703  0.181673

# %%
# SOlution 4

# Write a code to find the following statistical measurements for the above dataframe df1:

# (i) 	mean of each and every column present in the dataframe.

# (ii) standard deviation of column, ‘column_2

mean_of_columns = df1[['column_1', 'column_2', 'column_3', 'column_4', 'column_5', 'column_6']].mean()
print("Mean of each columns")
mean_of_columns
# Out:
# Mean of each columns
# column_1    0.605973
# column_2    0.455301
# column_3    0.420275
# column_4    0.659397
# column_5    0.529171
# column_6    0.373224
# dtype: float64

# %%
std_of_columns = df1['column_2'].std()
print("standard deviation of column, ‘column_2")
std_of_columns
# Out:
# standard deviation of column, ‘column_2
# 0.318480627261279

# %%
# Solution 5

# Replace the data present in the second row of column, ‘column_2’ by a string variable then find the
# mean of column, column_2.

# If you are getting errors in executing it then explain why.

# [Hint: To replace the data use df1.loc[] and equate this to string data of your choice.]

df1.loc[df1['column_2'] == 0.362043, 'column_2'] = 'a'
df1
# Out:
#    column_1  column_2  column_3  column_4  column_5  column_6
# 1  0.511025  0.694619  0.036682  0.199129  0.095474  0.662907
# 2  0.429061  0.362043  0.950979  0.923716  0.516688  0.037985
# 3  0.884393  0.098448  0.142266  0.782230  0.194359  0.184436
# 4  0.991547  0.723847  0.516183  0.507132  0.920445  0.437374
# 5  0.677529  0.772872  0.022432  0.606828  0.894357  0.734966
# 6  0.142280  0.079979  0.853109  0.937346  0.553703  0.181673

# %%
#Solution 6

# What do you understand about the windows function in pandas and list the types of windows functions?

# Pandas Window functions are functions where the input values are taken from a “window” of one or more rows in a series or a table and calculation is performed over them. 
# The word window means the number of rows between the two boundaries by which we perform calculations including the boundary rows.

# pandas supports 4 types of windowing operations:

# Rolling window: Generic fixed or variable sliding window over the values.

# Weighted window: Weighted, non-rectangular window supplied by the scipy.signal library.

# Expanding window: Accumulating window over the values.

# Exponentially Weighted window: Accumulating and exponentially weighted window over the values.

# %%
# Solution 7

# Write a code to print only the current month and year at the time of answering this question.
# [Hint: Use pandas.datetime function]


import datetime
from datetime import datetime

month = datetime.now().month
year = datetime.now().year

print("Current month: ", month)
print("Current year: ", year)
# Out:
# Current month:  11
# Current year:  2023

# %%
# Solution 8

# Write a Python program that takes in two dates as input (in the format YYYY-MM-DD) and
# calculates the difference between them in days, hours, and minutes using Pandas time delta. The
# program should prompt the user to enter the dates and display the result.




#Specified date
#d1 = datetime.strptime('2020-01-01 01:00:00', '%Y-%m-%d %H:%M:%S')
#Current date
#d2 = datetime.now()



from datetime import datetime, time
d1 = input("Enter the first date in the format YYYY-MM-DD H:M:S")
d2 = input("Enter the second date in the format YYYY-MM-DD H:M:S")
first_date = datetime.strptime(d1, '%Y-%m-%d %H:%M:%S')
second_date = datetime.strptime(d2, '%Y-%m-%d %H:%M:%S')
timedelta = second_date - first_date
print(timedelta)
seconds=timedelta.days * 24 * 3600 + timedelta.seconds
minutes, seconds = divmod(seconds, 60)
hours, minutes = divmod(minutes, 60)
days, hours = divmod(hours, 24)
print("Days :",days)
print("Hours :",hours)
print("Minutes :",minutes)
print("Seconds :",seconds)
# Out:
# Enter the first date in the format YYYY-MM-DD H:M:S 1983-01-01 5:23:55
# Enter the second date in the format YYYY-MM-DD H:M:S 2023-11-19 10:30:30
# 14932 days, 5:06:35
# Days : 14932
# Hours : 5
# Minutes : 6
# Seconds : 35

# %%
# Solution 9

# Write a Python program that reads a CSV file containing categorical data and converts a specified
# column to a categorical data type. The program should prompt the user to enter the file path, column
# name, and category order, and then display the sorted data.
# "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
import pandas as pd

file_path = input('Enter the path of a CSV file')
column_name = input('Enter the column name')
df = pd.read_csv(file_path)
df

# cat = pd.Categorical(df[column_name])

df[column_name] = pd.Categorical(df[column_name])
df_new = df.sort_values(column_name)
df_new
# Out:
# Enter the path of a CSV file https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv
# Enter the column name Survived
#      PassengerId Survived  Pclass  ...      Fare Cabin  Embarked
# 0              1        0       3  ...    7.2500   NaN         S
# 519          520        0       3  ...    7.8958   NaN         S
# 521          522        0       3  ...    7.8958   NaN         S
# 522          523        0       3  ...    7.2250   NaN         C
# 524          525        0       3  ...    7.2292   NaN         C
# ..           ...      ...     ...  ...       ...   ...       ...
# 546          547        1       2  ...   26.0000   NaN         S
# 215          216        1       1  ...  113.2750   D36         C
# 216          217        1       3  ...    7.9250   NaN         S
# 218          219        1       1  ...   76.2917   D15         C
# 445          446        1       1  ...   81.8583   A34         S
#
# [891 rows x 12 columns]

# %%
# Solution 10

# Write a Python program that reads a CSV file containing sales data for different products and
# visualizes the data using a stacked bar chart to show the sales of each product category over time. The
# program should prompt the user to enter the file path and display the chart.

import matplotlib.pyplot as plt
import pandas as pd

# filepath: Dataset/Adidas_US_Sales_Datasets.csv
file_path = input('Enter the path of a CSV file')
df9 = pd.read_csv(file_path)

X = list(df9['Product'])
Y1 = list(df9['Invoice Date'])
Y2 = list(df9['Total Sales'])

plt.bar(X,Y1, color="Yellow")
plt.bar(X, Y2, bottom = Y1, color = 'Green')
plt.show()
df9
# Out:
# Enter the path of a CSV file Dataset/Adidas_US_Sales_Datasets.csv
#          Retailer  Retailer ID  Invoice Date     Region          State  \
# 0     Foot Locker      1185732         43831  Northeast       New York
# 1     Foot Locker      1185732         43832  Northeast       New York
# 2     Foot Locker      1185732         43833  Northeast       New York
# 3     Foot Locker      1185732         43834  Northeast       New York
# 4     Foot Locker      1185732         43835  Northeast       New York
# ...           ...          ...           ...        ...            ...
# 9643  Foot Locker      1185732         44220  Northeast  New Hampshire
# 9644  Foot Locker      1185732         44220  Northeast  New Hampshire
# 9645  Foot Locker      1185732         44249  Northeast  New Hampshire
# 9646  Foot Locker      1185732         44249  Northeast  New Hampshire
# 9647  Foot Locker      1185732         44249  Northeast  New Hampshire
#
# ...

# %%
# Solution 11

# You are given a CSV file containing student data that includes the student ID and their test score. Write
# a Python program that reads the CSV file, calculates the mean, median, and mode of the test scores, and
# displays the results in a table.

import pandas as pd

file_path = input("Enter file path of a CSV file")

df10 = pd.read_csv(file_path)
# df10.dtypes

mean_of_scores = df10['Test Score'].mean()
median_of_scores = df10['Test Score'].median()
mode_of_scores = df10['Test Score'].mode()

print('|Statistic'+'\t|'+'Value')
print('|Mean ' + '\t\t|', mean_of_scores)
print('|Median ' + '\t\t|',median_of_scores)
print('|Mode' +'\t\t|',mode_of_scores)
# Out:
# Enter file path of a CSV file Dataset/Student_scores.csv
# Statistic	|Value
# Mean 		| 83.5
# Median 		| 85.0
# Mode		| 0    85
# Name: Test Score, dtype: int64
